# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamm105/R_lAB/blob/main/R_lab_miniproject_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id <- "1i-pI1CQYvqSY5tc0tuT-epZ6HlxUBYMF" # google file ID
data <- read.csv(sprintf("https://docs.google.com/uc?id=%s&export=download", id), na.strings=c("","NA"))
data
# Out:
#     Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# 1    6          148     72            35              0     33.6
# 2    1           85     66            29              0     26.6
# 3    8          183     64             0              0     23.3
# 4    1           89     66            23             94     28.1
# 5    0          137     40            35            168     43.1
# 6    5          116     74             0              0     25.6
# 7    3           78     50            32             88     31.0
# 8   10          115      0             0              0     35.3
# 9    2          197     70            45            543     30.5
# 10   8          125     96             0              0      0.0
# 11   4          110     92             0              0     37.6
# 12  10          168     74             0              0     38.0
# 13  10          139     80             0              0     27.1
# 14   1          189     60            23            846     30.1
# 15   5          166     72            19            175     25.8
# 16   7          100      0             0              0     30.0
# 17   0          118     84            47            230     45.8
# 18   7          107     74             0              0       NA
# 19   1          103     30            38             83     43.3
# 20   1          115     70            30             96     34.6
# 21   3          126     88            41            235     39.3
# 22   8           99     84             0              0     35.4
# 23   7          196     90             0              0       NA
# 24   9          119     80            35              0     29.0
# 25  11          143     94            33            146     36.6
# 26  10          125     70            26            115     31.1
# 27   7          147     76             0              0     39.4
# 28   1           97     66            15            140     23.2
# 29  13          145     82            19             NA     22.2
# 30   5          117     92             0              0       NA
# ⋮   ⋮           ⋮       ⋮             ⋮             ⋮       ⋮
# 739  2           99     60            17            160     36.6
# 740  1          102     74             0              0     39.5
# 741 11          120     80            37            150     42.3
# 742  3          102     44            20             94     30.8
# 743  1          109     58            18             NA     28.5
# 744  9          140     94             0              0     32.7
# 745 13          153     88            37            140     40.6
# 746 12          100     84            33            105     30.0
# 747  1          147     94            41              0     49.3
# 748  1           81     74            41             57     46.3
# 749  3          187     70            22            200     36.4
# 750  6          162     62             0              0     24.3
# 751  4          136     70             0              0     31.2
# 752  1          121     78            39             74     39.0
# 753  3          108     62            24              0     26.0
# 754  0          181     88            44            510     43.3
# 755  8          154     78            32              0     32.4
# 756  1          128     88            39             NA     36.5
# 757  7          137     90            41              0     32.0
# 758  0          123     72             0              0     36.3
# 759  1          106     76             0              0     37.5
# 760  6          190     92             0              0     35.5
# 761  2           88     58            26             16     28.4
# 762  9          170     74            31              0     44.0
# 763  9           89     62             0              0     22.5
# 764 10          101     76            48            180     32.9
# 765  2          122     70            27              0     36.8
# 766  5          121     72            23            112     26.2
# 767  1          126     60             0              0     30.1
# 768  1           93     70            31              0     30.4
#     DiabetesPedigreeFunction Age Outcome
# 1   0.627                    50  1
# 2   0.351                    31  0
# 3   0.672                    32  1
# 4   0.167                    21  0
# 5   2.288                    33  1
# 6   0.201                    30  0
# 7   0.248                    26  1
# 8   0.134                    29  0
# 9   0.158                    53  1
# 10  0.232                    54  1
# 11  0.191                    30  0
# 12  0.537                    34  1
# 13  1.441                    57  0
# 14  0.398                    59  1
# 15  0.587                    51  1
# 16  0.484                    32  1
# 17  0.551                    31  1
# 18  0.254                    31  1
# 19  0.183                    33  0
# 20  0.529                    32  1
# 21  0.704                    27  0
# 22  0.388                    50  0
# 23  0.451                    41  1
# 24  0.263                    29  1
# 25  0.254                    51  1
# 26  0.205                    41  1
# 27  0.257                    43  1
# 28  0.487                    22  0
# 29  0.245                    57  0
# 30  0.337                    38  0
# ⋮   ⋮                        ⋮   ⋮
# 739 0.453                    21  0
# 740 0.293                    42  1
# 741 0.785                    48  1
# 742 0.400                    26  0
# 743 0.219                    22  0
# 744 0.734                    45  1
# 745 1.174                    39  0
# 746 0.488                    46  0
# 747 0.358                    27  1
# 748 1.096                    32  0
# 749 0.408                    36  1
# 750 0.178                    50  1
# 751 1.182                    22  1
# 752 0.261                    28  0
# 753 0.223                    25  0
# 754 0.222                    26  1
# 755 0.443                    45  1
# 756 1.057                    37  1
# 757 0.391                    39  0
# 758 0.258                    52  1
# 759 0.197                    26  0
# 760 0.278                    66  1
# 761 0.766                    22  0
# 762 0.403                    43  1
# 763 0.142                    33  0
# 764 0.171                    63  0
# 765 0.340                    27  0
# 766 0.245                    30  0
# 767 0.349                    47  1
# 768 0.315                    23  0

# %%
# a. summarize the entire data using apropriate R Command.
library(dplyr)

summary(data)
# Out:
#   Pregnancies        Glucose      BloodPressure    SkinThickness
#  Min.   : 0.000   Min.   :  0.0   Min.   :  0.00   Min.   : 0.00
#  1st Qu.: 1.000   1st Qu.: 99.0   1st Qu.: 62.00   1st Qu.: 0.00
#  Median : 3.000   Median :117.0   Median : 72.00   Median :23.00
#  Mean   : 3.845   Mean   :120.9   Mean   : 69.11   Mean   :20.54
#  3rd Qu.: 6.000   3rd Qu.:140.2   3rd Qu.: 80.00   3rd Qu.:32.00
#  Max.   :17.000   Max.   :199.0   Max.   :122.00   Max.   :99.00
#
#     Insulin            BMI        DiabetesPedigreeFunction      Age
#  Min.   :  0.00   Min.   : 0.00   Min.   :0.0780           Min.   :21.00
#  1st Qu.:  0.00   1st Qu.:27.30   1st Qu.:0.2437           1st Qu.:24.00
#  Median : 18.00   Median :32.00   Median :0.3725           Median :29.00
#  Mean   : 77.84   Mean   :31.97   Mean   :0.4719           Mean   :33.24
#  3rd Qu.:125.00   3rd Qu.:36.58   3rd Qu.:0.6262           3rd Qu.:41.00
#  Max.   :846.00   Max.   :67.10   Max.   :2.4200           Max.   :81.00
#  NA's   :13       NA's   :6
#     Outcome
#  Min.   :0.000
#  1st Qu.:0.000
#  Median :0.000
#  Mean   :0.349
#  3rd Qu.:1.000
#  Max.   :1.000

# %%
# b. show class of variable holding data
class(data)
# Out:
# [1] "data.frame"

# %%
# d. select any 2 atributes that are continuous valued and create a subset of original data with only those columns. 
# (e.g. sample_data(col1,col2, col3) is stored in variable my_data where as variable data_slice has only col2 and col3 and no other columns. Num of rows in both must be same.)


data_slice <- data %>% select(Glucose:Insulin)
summary(data_slice)
# Out:
#     Glucose      BloodPressure    SkinThickness      Insulin
#  Min.   :  0.0   Min.   :  0.00   Min.   : 0.00   Min.   :  0.00
#  1st Qu.: 99.0   1st Qu.: 62.00   1st Qu.: 0.00   1st Qu.:  0.00
#  Median :117.0   Median : 72.00   Median :23.00   Median : 18.00
#  Mean   :120.9   Mean   : 69.11   Mean   :20.54   Mean   : 77.84
#  3rd Qu.:140.2   3rd Qu.: 80.00   3rd Qu.:32.00   3rd Qu.:125.00
#  Max.   :199.0   Max.   :122.00   Max.   :99.00   Max.   :846.00
#                                                   NA's   :13

# %%
# e. Write R function to sample tuples starting at index N to N+m from any data set provided.
bb <- data['Age']
sample(bb[1:10,])
# Out:
#  [1] 31 53 21 33 26 50 29 32 54 30

# %%
# a. find out how many values are missing in each of the columns of your data set.
tar <- data$Age
sapply(data, function(tar) sum(is.na(tar)))
# Out:
#              Pregnancies                  Glucose            BloodPressure
#                        0                        0                        0
#            SkinThickness                  Insulin                      BMI
#                        0                       13                        6
# DiabetesPedigreeFunction                      Age                  Outcome
#                        0                        0                        0

# %%
# b. select colum with more than 10% values missing for deletation. Create new copy of dataset
# that has one less column call it sample_data_1less.

## Remove columns with more than 10% NA
dataless1 <-data[, which(colMeans(!is.na(data)) > 0.1)]

# %%
# c. Find 5 point summary of all remaining columns with numric attributes
summary(dataless1)
# Out:
#   Pregnancies        Glucose      BloodPressure    SkinThickness
#  Min.   : 0.000   Min.   :  0.0   Min.   :  0.00   Min.   : 0.00
#  1st Qu.: 1.000   1st Qu.: 99.0   1st Qu.: 62.00   1st Qu.: 0.00
#  Median : 3.000   Median :117.0   Median : 72.00   Median :23.00
#  Mean   : 3.845   Mean   :120.9   Mean   : 69.11   Mean   :20.54
#  3rd Qu.: 6.000   3rd Qu.:140.2   3rd Qu.: 80.00   3rd Qu.:32.00
#  Max.   :17.000   Max.   :199.0   Max.   :122.00   Max.   :99.00
#
#     Insulin            BMI        DiabetesPedigreeFunction      Age
#  Min.   :  0.00   Min.   : 0.00   Min.   :0.0780           Min.   :21.00
#  1st Qu.:  0.00   1st Qu.:27.30   1st Qu.:0.2437           1st Qu.:24.00
#  Median : 18.00   Median :32.00   Median :0.3725           Median :29.00
#  Mean   : 77.84   Mean   :31.97   Mean   :0.4719           Mean   :33.24
#  3rd Qu.:125.00   3rd Qu.:36.58   3rd Qu.:0.6262           3rd Qu.:41.00
#  Max.   :846.00   Max.   :67.10   Max.   :2.4200           Max.   :81.00
#  NA's   :13       NA's   :6
#     Outcome
#  Min.   :0.000
#  1st Qu.:0.000
#  Median :0.000
#  Mean   :0.349
#  3rd Qu.:1.000
#  Max.   :1.000

# %%
# d. For attribute having maximum spread delete all tuples that have value less than the mean of the
# attribute selected. Count the number of tuples reamining in the sampled dataset.

m <- mean(data$Age, na.rm = FALSE)
m

df2 <- subset(data, data$Age< m)
summary(df2$Age)
print('Rows before row deletion: ')
nrow(data)
print('Rows before row deletion: ')
nrow(df2)
# Out:
# [1] 33.24089
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   21.00   22.00   25.00   25.47   28.00   33.00
# [1] "Rows before row deletion: "
# [1] 768
# [1] "Rows before row deletion: "
# [1] 474

# %%
# a. print the 5 point statistical summary for any 2 numeric attributes from your data set
fivenum(data$Age) 
fivenum(data$Glucose)
# Out:
# [1] 21 24 29 41 81
# [1]   0.0  99.0 117.0 140.5 199.0

# %%
# b. select 2 atributes have closest mean value and draw a scatter plot with proper x and labelsloi
# ntt and title (for plotting you must use R library functions or gnuplot and not matplotlib )
means<- colMeans(data[sapply(data, is.numeric)] )
means

library(ggplot2)

age<-data$Age
glucose<-data$Glucose
plot(age , glucose , main = "Scatterplot" , xlab = "age" , ylab = "glucose" , las = 1 , xlim = c(0,50) , col = 4 )
# Out:
#              Pregnancies                  Glucose            BloodPressure
#                3.8450521              120.8945312               69.1054688
#            SkinThickness                  Insulin                      BMI
#               20.5364583                       NA                       NA
# DiabetesPedigreeFunction                      Age                  Outcome
#                0.4718763               33.2408854                0.3489583
# Plot with title “Scatterplot”

# %%
# e. Write a R function to plot histogram of some specific input attribute for any data set provided
new.function <- function(age) {
   hist(age)
}

new.function(age)
# Out:
# Plot with title “Histogram of age”

# %%
# c. Find coefficient of correlation using some R library function between above 2 attributes
cor(age,glucose, method = c("pearson", "kendall", "spearman"))
# Out:
# [1] 0.2635143

# %%
boxplot(age,glucose)
title("age vs. glucose")
# Out:
# Plot with title “age vs. glucose”
